# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing

# %%
data = fetch_california_housing()
x = data['data']
y = data['target']
x[:3,:]
y[:3]
x.shape
m = len(x)
m
# Out:
# 20640

# %%
plt.plot(x,y,'ro',ms='5',mec='k')#should be n-dimensional find you way around that
# Out:
# [<matplotlib.lines.Line2D at 0x1f86edfa2e8>,
#  <matplotlib.lines.Line2D at 0x1f86edfa518>,
#  <matplotlib.lines.Line2D at 0x1f86edfa630>,
#  <matplotlib.lines.Line2D at 0x1f86edfa780>,
#  <matplotlib.lines.Line2D at 0x1f86edfa8d0>,
#  <matplotlib.lines.Line2D at 0x1f86edfaa20>,
#  <matplotlib.lines.Line2D at 0x1f86edfab70>,
#  <matplotlib.lines.Line2D at 0x1f86edfacc0>]

# %%
def computeCost(x,y,theta):
    y_pred = np.dot(x,theta)
    J = (0.5*1/m)*sum((y_pred-y)**2)
    return J

# %%
computeCost(x,y,theta=np.zeros((8,1)))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-20-7efac389ef3d> in <module>
# ----> 1 computeCost(x,y,theta=np.zeros((8,1)))
#
# <ipython-input-19-0361f49fa088> in computeCost(x, y, theta)
#       1 def computeCost(x,y,theta):
#       2     y_pred = np.dot(x,theta)
# ----> 3     J = (0.5*1/m)*sum((y_pred-y)**2)
#       4     return J
#
# MemoryError:
